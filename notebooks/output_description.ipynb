# %% [markdown]
# # Requested Model Outputs
#
# #### NOTE: If a variable is missing in your reporting, do not fill it with values of zero, -999, etc, instead, simply do not fill the variable field or set the values to NaN.
#
# Output variables are requested in three categories for LES:

# %% [markdown]
# ### imports

# %%
import pandas as pd
#maybe openpyxl is needed as well

# %% [markdown]
# ### read data from sheets

# %%
vars_1d_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1EwOqkozsgS0plJyQS-j51eXRQbgRyIU7Bq16Zhh5U50/export?gid=0&format=xlsx',
                              sheet_name='1D')
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
vars_1d_list
# Out:
#                                    standard_name variable_id    units  \
# 0                                           time        time        s
# 1                                   layer_center        zlev        m
# 2                                     layer_edge          ze        m
# 3                            surface_temperature          ts        K
# 4                              walls_temperature         tsw        K
# 5                      surface_friction_velocity       ustar    m s-1
# 6                         roof_friction_velocity      ustarf    m s-1
# 7   surface_roughness_length_for_momentum_in_air          z0        m
# 8       surface_roughness_length_for_heat_in_air         z0h        m
# 9     walls_roughness_length_for_momentum_in_air         z0w        m
# 10        walls_roughness_length_for_heat_in_air        z0wh        m
# 11                                         u_avg        z0wh        m
# ...

# %%
vars_2d_list = pd.read_excel('https://docs.google.com/spreadsheets/d/1EwOqkozsgS0plJyQS-j51eXRQbgRyIU7Bq16Zhh5U50/export?gid=1677513788&format=xlsx',
                              sheet_name='2D')
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
vars_2d_list
# Out:
#       standard_name variable_id units dimensions  \
# 0              time        time     s       time
# 1      layer_center        zlev     m       zlev
# 2        layer_edge          ze     m         ze
# 3        layer_edge          ze     m         ze
# 4                 x           x     m          x
# 5                 y           y     m          y
# 6                xe          xe     m         xe
# 7                ye          ye     m         ye
# 8  buildings_height     bheight     m        x,y
#
#                         comment (averaging should be discussed)
# 0             dimension, seconds since beging of the experiment
# 1  dimension, altitude of mid-level points above ground surface
# 2   dimension, altitude of layer edges including ground surface
# 3   dimension, altitude of layer edges including ground surface
# 4                                   dimension, grid cell center
# 5                                   dimension, grid cell center
# ...
